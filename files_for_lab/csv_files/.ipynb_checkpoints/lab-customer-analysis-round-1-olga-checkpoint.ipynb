# %%
import pandas as pd

# %% [markdown]
# Read the three files into python as dataframes

# %%
file1 = pd.read_csv("file1.csv")

# %%
file2 = pd.read_csv("file2.csv")

# %%
file3 = pd.read_csv("file3.csv")

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# Show the DataFrame's shape.

# %%
file1.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
file2.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# dtype: object

# %%
file3.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints      int64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %% [markdown]
# Standardize header names.

# %%
cols1 = [file1.columns[i].lower().replace(' ','_') for i in range (len(file1.columns))]

# %%
cols1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
cols2 = [file2.columns[i].lower().replace(' ','_') for i in range (len(file2.columns))]

# %%
cols2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
cols3 = [file3.columns[i].lower().replace(' ','_').replace('state','st') for i in range (len(file3.columns))]

# %%
cols3
# Out:
# ['customer',
#  'st',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %% [markdown]
# Rearrange the columns in the dataframe as needed

# %%
file1.columns = cols1

# %%
file2.columns = cols2

# %%
file3.columns = cols3

# %%
file2 = file2[['customer','st','gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount']]

# %%
file3 = file3[['customer','st','gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount']]

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
file3
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %% [markdown]
# Concatenate the three dataframes

# %%
data = pd.concat([file1,file2,file3]).reset_index(drop=True)

# %%
data
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Which columns are numerical?

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %% [markdown]
# Numerical columns are: income, monthly_premium_auto and total_claim_ammount

# %% [markdown]
# Which columns are categorical?

# %% [markdown]
# Categorical columns are: customer, st, gender, education, customer_lifetime_value, number_of_open_complaints, policy_types, vehicle_class

# %% [markdown]
# Understand the meaning of all columns

# %% [markdown]
# Perform the data cleaning operations mentioned so far in class":
# Delete the column education and the number of open complaints from the dataframe.

# %%
data = data.drop(columns=["education","number_of_open_complaints"])
display(data)
# Out:
#       customer          st gender customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].astype(str)

# %% [markdown]
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].str.replace("%","").str.strip().astype(float)*100

# %%
data['customer_lifetime_value']
# Out:
# 0                 NaN
# 1        6.979536e+07
# 2        1.288743e+08
# 3        7.645862e+07
# 4        5.363076e+07
#              ...
# 12069    2.340599e+06
# 12070    3.096511e+05
# 12071    8.163890e+05
# 12072    7.524442e+05
# 12073    2.611837e+05
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %% [markdown]
# Check for duplicate rows in the data and remove if any.

# %%
duplicatedRows = data[data.duplicated()]

# %%
duplicatedRows
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 1072      NaN         NaN    NaN                      NaN      NaN
# 1073      NaN         NaN    NaN                      NaN      NaN
# 1074      NaN         NaN    NaN                      NaN      NaN
# 1075      NaN         NaN    NaN                      NaN      NaN
# 1076      NaN         NaN    NaN                      NaN      NaN
# ...       ...         ...    ...                      ...      ...
# 4006      NaN         NaN    NaN                      NaN      NaN
# 4007      NaN         NaN    NaN                      NaN      NaN
# 4008  GS98873     Arizona      F               32391247.0  16061.0
# 4009  CW49887  California      F               46268011.0  79487.0
# 4010  MY31220  California      F               89970402.0  54230.0
#
#       monthly_premium_auto    policy_type  vehicle_class  total_claim_amount
# 1072                   NaN            NaN            NaN                 NaN
# ...

# %%
clean_data = data.drop_duplicates()
clean_data
# Out:
#       customer          st gender  customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F             6.979536e+07      0.0
# 2      AI49188      Nevada      F             1.288743e+08  48767.0
# 3      WW63253  California      M             7.645862e+07      0.0
# 4      GA49547  Washington      M             5.363076e+07  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# ...

# %%
clean_data_duplicatedRows = clean_data[clean_data.duplicated()]
clean_data_duplicatedRows
# Out:
# Empty DataFrame
# Columns: [customer, st, gender, customer_lifetime_value, income, monthly_premium_auto, policy_type, vehicle_class, total_claim_amount]
# Index: []
